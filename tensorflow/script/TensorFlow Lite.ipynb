# %% [markdown]
# # Version 1

# %%
# !python C:/Users/hogbal/Desktop/RUP/object_detection/models/research/object_detection/export_tflite_graph_tf2.py \
    --pipeline_config_path C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/exported-models/MobileLite_v1/pipeline.config \
    --trained_checkpoint_dir C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/exported-models/MobileLite_v1/checkpoint \
    --output_directory C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1
# Out:
# 2021-03-07 19:00:26.567110: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# 2021-03-07 19:00:29.062248: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-03-07 19:00:29.062784: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library nvcuda.dll
# 2021-03-07 19:00:29.076992: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: GeForce GTX 1060 6GB computeCapability: 6.1
# coreClock: 1.7335GHz coreCount: 10 deviceMemorySize: 6.00GiB deviceMemoryBandwidth: 178.99GiB/s
# 2021-03-07 19:00:29.077010: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library cudart64_110.dll
# ...

# %%
import tensorflow as tf

saved_model_dir = 'C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/saved_model'


# Convert the model
converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir) # path to the SavedModel directory
tflite_model = converter.convert()

# Save the model.
with open('C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/detect.tflite', 'wb') as f:
  f.write(tflite_model)

# %% [markdown]
# # Test

# %%
import tensorflow as tf

saved_model_dir = 'C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/saved_model'

converter = tf.lite.TFLiteConverter.from_saved_model(saved_model_dir,signature_keys=['serving_default'])
#converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.experimental_new_converter = True
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS, tf.lite.OpsSet.SELECT_TF_OPS]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS]
#converter.optimizations = [tf.lite.Optimize.DEFAULT]
#converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8,tf.lite.OpsSet.TFLITE_BUILTINS]

tflite_model = converter.convert()

with tf.io.gfile.GFile('C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/detect.tflite', 'wb') as f:
  f.write(tflite_model)
 
#Used for adding metadata
from tflite_support import metadata as _metadata
populator = _metadata.MetadataPopulator.with_model_file("C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/detect.tflite")
populator.load_associated_files(["C:/Users/hogbal/Desktop/RUP/object_detection/workspace/training_rup/mobile/MobileLite_v1/labelmap.txt"])
populator.populate()
