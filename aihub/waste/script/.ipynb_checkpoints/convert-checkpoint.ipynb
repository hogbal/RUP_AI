# %% [markdown]
# # Import

# %%
import json
import os
import shutil
from tqdm import tqdm
from glob import glob

# %% [markdown]
# # convert func

# %%
def obj_class(data): #플라스틱류, 캔류, 종이류, 유리병류, 페트병류
    if(data == "플라스틱류"):
        return 0
    elif(data == "캔류"):
        return 1
    elif(data == "종이류"):
        return 2
    elif(data == "유리병류"):
        return 3
    elif(data == "페트병류"):
        return 4
    else:
        print("error!")
        print(data)
        exit(1)

# %%
def convert(json_datas, yolo_txt_path, yolo_img_path):
    for json_data in tqdm(json_datas):
        filename = os.path.basename(json_data).split('.')[0]
        yolo = open(f'{yolo_txt_path}/{filename}.txt','w')
        
        with open(json_data, 'r', encoding="utf-8") as f:
            json_data_parse = json.load(f)
        
        width, height = list(map(int,json_data_parse["RESOLUTION"].split("*")))
        
        check = False
        
        for obj in json_data_parse["Bounding"]:
            if(obj["Drawing"]=="BOX"):
                met = obj_class(obj["CLASS"])
                x1 = int(obj["x1"])
                y1 = int(obj["y1"])
                x2 = int(obj["x2"])
                y2 = int(obj["y2"])

                dw = 1./width
                dh = 1./height
                x = (x1 + x2)/2.0
                y = (y1 + y2)/2.0
                w = x2 - x1
                h = y2 - y1
                x = x*dw
                w = w*dw
                y = y*dh
                h = h*dh

                yolo.write(f'{met} {x:.6f} {y:.6f} {w:.6f} {h:.6f}\n')
                check = True
        yolo.close()
        
        try:
            if(check):
                shutil.copyfile(f'{os.path.dirname(json_data)}/{filename}.jpg'.replace("json","img"),f'{yolo_img_path}/{filename}.jpg')
            else:
                os.remove(f'{yolo_txt_path}/{filename}.txt')
        except:
            os.remove(f'{yolo_txt_path}/{filename}.txt')

# %% [markdown]
# # File Load

# %%
train_img_path = "/home/jovyan/work/Training/img"
train_json_path = "/home/jovyan/work/Training/json"
train_yolo_img_path = "/home/jovyan/work/Training/yolo/img"
train_yolo_txt_path = "/home/jovyan/work/Training/yolo/txt"
train_img = glob(train_img_path+"/*/*.jpg")
train_json = glob(train_json_path+"/*/*.Json")

test_img_path = "/home/jovyan/work/Validation/img"
test_json_path = "/home/jovyan/work/Validation/json"
test_yolo_img_path = "/home/jovyan/work/Validation/yolo/img"
test_yolo_txt_path = "/home/jovyan/work/Validation/yolo/txt"
test_img = glob(test_img_path+"/*/*.jpg")
test_json = glob(test_json_path+"/*/*.Json")

print('-------train dataset------')
print('img : '+str(len(train_img)))
print('json : '+str(len(train_json)))

print('-------test dataset------')
print('img : '+str(len(test_img)))
print('json : '+str(len(test_json)))
# Out:
# -------train dataset------
# img : 167543
# json : 203122
# -------test dataset------
# img : 25426
# json : 25426

# %% [markdown]
# # Convert

# %%
convert(train_json, train_yolo_txt_path, train_yolo_img_path)
convert(test_json, test_yolo_txt_path, test_yolo_img_path)
# Out:
#   0%|                                                              | 66/203122 [00:00<10:08, 333.91it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   0%|                                                             | 159/203122 [00:00<07:58, 424.35it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   0%|                                                             | 277/203122 [00:00<07:39, 441.35it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   0%|▏                                                            | 443/203122 [00:00<06:36, 511.74it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   0%|▏                                                            | 546/203122 [00:01<06:53, 489.74it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   0%|▏                                                            | 597/203122 [00:01<06:52, 491.53it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   0%|▏                                                            | 749/203122 [00:01<06:55, 487.34it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   0%|▎                                                            | 865/203122 [00:01<06:18, 534.35it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
#   0%|▎                                                            | 919/203122 [00:01<07:18, 461.45it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▎                                                           | 1091/203122 [00:02<06:15, 537.62it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▎                                                           | 1146/203122 [00:02<06:46, 497.30it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▎                                                           | 1264/203122 [00:02<06:16, 536.21it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▍                                                           | 1428/203122 [00:02<06:31, 515.10it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▍                                                           | 1492/203122 [00:03<06:09, 545.50it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▍                                                           | 1603/203122 [00:03<06:29, 517.46it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▌                                                           | 1720/203122 [00:03<06:31, 513.94it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   1%|▌                                                           | 1823/203122 [00:03<07:04, 474.35it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▌                                                           | 1936/203122 [00:03<06:51, 489.06it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▌                                                           | 2034/203122 [00:04<07:33, 443.08it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   1%|▋                                                           | 2132/203122 [00:04<07:13, 463.19it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▋                                                           | 2254/203122 [00:04<06:25, 520.47it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   1%|▋                                                           | 2314/203122 [00:04<06:10, 542.36it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▋                                                           | 2418/203122 [00:05<07:36, 439.76it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▋                                                           | 2517/203122 [00:05<07:27, 447.89it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▊                                                           | 2622/203122 [00:05<07:10, 465.85it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▊                                                           | 2728/203122 [00:05<06:42, 497.43it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
#   1%|▊                                                           | 2779/203122 [00:05<07:50, 425.55it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   1%|▊                                                           | 2876/203122 [00:06<07:50, 425.58it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   1%|▉                                                           | 2970/203122 [00:06<07:32, 442.10it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|▉                                                           | 3067/203122 [00:06<07:44, 430.25it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|▉                                                           | 3156/203122 [00:06<07:50, 425.15it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|▉                                                           | 3245/203122 [00:06<07:41, 432.85it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|▉                                                           | 3331/203122 [00:07<08:28, 392.58it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█                                                           | 3413/203122 [00:07<08:31, 390.55it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█                                                           | 3492/203122 [00:07<08:35, 386.97it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█                                                           | 3599/203122 [00:07<07:21, 452.00it/s]
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█                                                           | 3645/203122 [00:07<08:25, 394.70it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|█                                                           | 3759/203122 [00:08<07:04, 469.18it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|█▏                                                          | 3856/203122 [00:08<07:14, 458.62it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█▏                                                          | 3946/203122 [00:08<08:21, 396.99it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█▏                                                          | 4061/203122 [00:08<07:03, 470.35it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|█▏                                                          | 4156/203122 [00:09<07:36, 435.90it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
#   2%|█▎                                                          | 4249/203122 [00:09<07:50, 423.09it/s]
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
#   2%|█▎                                                          | 4335/203122 [00:09<08:33, 387.42it/s]
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 페트병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
# error!
# 유리병류
#   2%|█▎                                                          | 4394/203122 [00:09<07:30, 441.39it/s]
